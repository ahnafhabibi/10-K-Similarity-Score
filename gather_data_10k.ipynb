# %%
pip install datasets
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting datasets
#   Downloading datasets-2.20.0-py3-none-any.whl (547 kB)
#      |████████████████████████████████| 547 kB 5.2 MB/s eta 0:00:01
# Collecting multiprocess
#   Downloading multiprocess-0.70.16-py39-none-any.whl (133 kB)
#      |████████████████████████████████| 133 kB 22.9 MB/s eta 0:00:01
# Requirement already satisfied: pandas in /Users/ahnafryan/Library/Python/3.9/lib/python/site-packages (from datasets) (2.2.2)
# Requirement already satisfied: packaging in /Users/ahnafryan/Library/Python/3.9/lib/python/site-packages (from datasets) (24.0)
# Collecting requests>=2.32.2
#   Downloading requests-2.32.3-py3-none-any.whl (64 kB)
#      |████████████████████████████████| 64 kB 9.1 MB/s  eta 0:00:01
# Collecting aiohttp
#   Downloading aiohttp-3.9.5-cp39-cp39-macosx_11_0_arm64.whl (390 kB)
#      |████████████████████████████████| 390 kB 32.2 MB/s eta 0:00:01
# Collecting tqdm>=4.66.3
#   Downloading tqdm-4.66.4-py3-none-any.whl (78 kB)
#      |████████████████████████████████| 78 kB 20.4 MB/s eta 0:00:01
# Collecting pyarrow-hotfix
#   Downloading pyarrow_hotfix-0.6-py3-none-any.whl (7.9 kB)
# Collecting dill<0.3.9,>=0.3.0
#   Downloading dill-0.3.8-py3-none-any.whl (116 kB)
#      |████████████████████████████████| 116 kB 41.4 MB/s eta 0:00:01
# Collecting filelock
#   Downloading filelock-3.15.4-py3-none-any.whl (16 kB)
# Collecting huggingface-hub>=0.21.2
#   Downloading huggingface_hub-0.23.4-py3-none-any.whl (402 kB)
#      |████████████████████████████████| 402 kB 41.1 MB/s eta 0:00:01
# Collecting pyyaml>=5.1
#   Downloading PyYAML-6.0.1-cp39-cp39-macosx_11_0_arm64.whl (174 kB)
#      |████████████████████████████████| 174 kB 39.4 MB/s eta 0:00:01
# Collecting xxhash
#   Downloading xxhash-3.4.1-cp39-cp39-macosx_11_0_arm64.whl (30 kB)
# Requirement already satisfied: numpy>=1.17 in /Users/ahnafryan/Library/Python/3.9/lib/python/site-packages (from datasets) (1.26.4)
# Collecting fsspec[http]<=2024.5.0,>=2023.1.0
#   Downloading fsspec-2024.5.0-py3-none-any.whl (316 kB)
#      |████████████████████████████████| 316 kB 49.9 MB/s eta 0:00:01
# Collecting pyarrow>=15.0.0
#   Downloading pyarrow-16.1.0-cp39-cp39-macosx_11_0_arm64.whl (26.0 MB)
#      |████████████████████████████████| 26.0 MB 2.1 MB/s eta 0:00:011
# Collecting multidict<7.0,>=4.5
#   Downloading multidict-6.0.5-cp39-cp39-macosx_11_0_arm64.whl (30 kB)
# Collecting aiosignal>=1.1.2
#   Downloading aiosignal-1.3.1-py3-none-any.whl (7.6 kB)
# Collecting attrs>=17.3.0
#   Downloading attrs-23.2.0-py3-none-any.whl (60 kB)
#      |████████████████████████████████| 60 kB 28.5 MB/s eta 0:00:01
# Collecting async-timeout<5.0,>=4.0
#   Downloading async_timeout-4.0.3-py3-none-any.whl (5.7 kB)
# Collecting frozenlist>=1.1.1
#   Downloading frozenlist-1.4.1-cp39-cp39-macosx_11_0_arm64.whl (53 kB)
#      |████████████████████████████████| 53 kB 10.2 MB/s eta 0:00:01
# Collecting yarl<2.0,>=1.0
#   Downloading yarl-1.9.4-cp39-cp39-macosx_11_0_arm64.whl (81 kB)
#      |████████████████████████████████| 81 kB 18.4 MB/s eta 0:00:01
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /Users/ahnafryan/Library/Python/3.9/lib/python/site-packages (from huggingface-hub>=0.21.2->datasets) (4.11.0)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/ahnafryan/Library/Python/3.9/lib/python/site-packages (from requests>=2.32.2->datasets) (2.2.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/ahnafryan/Library/Python/3.9/lib/python/site-packages (from requests>=2.32.2->datasets) (3.3.2)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/ahnafryan/Library/Python/3.9/lib/python/site-packages (from requests>=2.32.2->datasets) (2024.2.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/ahnafryan/Library/Python/3.9/lib/python/site-packages (from requests>=2.32.2->datasets) (3.7)
# Requirement already satisfied: pytz>=2020.1 in /Users/ahnafryan/Library/Python/3.9/lib/python/site-packages (from pandas->datasets) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /Users/ahnafryan/Library/Python/3.9/lib/python/site-packages (from pandas->datasets) (2024.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/ahnafryan/Library/Python/3.9/lib/python/site-packages (from pandas->datasets) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/site-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.15.0)
# Installing collected packages: multidict, frozenlist, yarl, attrs, async-timeout, aiosignal, tqdm, requests, pyyaml, fsspec, filelock, dill, aiohttp, xxhash, pyarrow-hotfix, pyarrow, multiprocess, huggingface-hub, datasets
#   Attempting uninstall: requests
#     Found existing installation: requests 2.31.0
#     Uninstalling requests-2.31.0:
#       Successfully uninstalled requests-2.31.0
# Successfully installed aiohttp-3.9.5 aiosignal-1.3.1 async-timeout-4.0.3 attrs-23.2.0 datasets-2.20.0 dill-0.3.8 filelock-3.15.4 frozenlist-1.4.1 fsspec-2024.5.0 huggingface-hub-0.23.4 multidict-6.0.5 multiprocess-0.70.16 pyarrow-16.1.0 pyarrow-hotfix-0.6 pyyaml-6.0.1 requests-2.32.3 tqdm-4.66.4 xxhash-3.4.1 yarl-1.9.4
# WARNING: You are using pip version 21.2.4; however, version 24.1.2 is available.
# You should consider upgrading via the '/Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
from datasets import load_dataset
import matplotlib.pyplot as plt

# %%
class TransformDataset:
    def __init__(self, dataset_name: str):
        """
        Initialize the TransformDataset class.

        Args:
            dataset_name (str): The name of the dataset to load from Hugging Face.
        """
        try:
            self.dataset = load_dataset(dataset_name)
        except Exception as e:
            raise ValueError(f"Error loading dataset: {e}")

    def hug_to_pandas(self) -> pd.DataFrame:
        """
        Convert Hugging Face dataset to a pandas DataFrame.

        Returns:
            pd.DataFrame: The converted DataFrame.
        """
        try:
            return pd.DataFrame(self.dataset["train"])
        except Exception as e:
            raise ValueError(f"Error converting dataset to DataFrame: {e}")

    def filter_df(self, df: pd.DataFrame, cols: list) -> pd.DataFrame:
        """
        Filter the DataFrame to include only specified columns.

        Args:
            df (pd.DataFrame): The DataFrame to filter.
            cols (list): The list of columns to include.

        Returns:
            pd.DataFrame: The filtered DataFrame.
        """
        return df[cols]

    def add_past_year_item(self, df: pd.DataFrame, main_col: str) -> pd.DataFrame:
        """
        Add a column with the past year's data for each 'cik' and 'company'.

        Args:
            df (pd.DataFrame): The DataFrame to process.
            main_col (str): The column name containing the data to shift.

        Returns:
            pd.DataFrame: The DataFrame with the added past year's data column.
        """
        df = df.sort_values(by=['cik', 'company', 'date'])
        df['past_year_data'] = df.groupby(['cik', 'company'])[main_col].shift(1)
        df=df.dropna()
        return df

# %%
Dataset=TransformDataset("jlohding/sp500-edgar-10k")
# Out:
# Downloading readme: 100%|██████████| 1.26k/1.26k [00:00<00:00, 2.03MB/s]
# Downloading data: 100%|██████████| 68.8M/68.8M [00:01<00:00, 37.5MB/s]
# Downloading data: 100%|██████████| 69.8M/69.8M [00:01<00:00, 48.1MB/s]
# Downloading data: 100%|██████████| 71.0M/71.0M [00:01<00:00, 40.9MB/s]
# Downloading data: 100%|██████████| 71.6M/71.6M [00:01<00:00, 36.1MB/s]
# Downloading data: 100%|██████████| 72.9M/72.9M [00:02<00:00, 33.0MB/s]
# Downloading data: 100%|██████████| 72.2M/72.2M [00:01<00:00, 46.1MB/s]
# Downloading data: 100%|██████████| 74.6M/74.6M [00:01<00:00, 41.2MB/s]
# Downloading data: 100%|██████████| 74.8M/74.8M [00:01<00:00, 44.1MB/s]
# Downloading data: 100%|██████████| 76.7M/76.7M [00:01<00:00, 53.9MB/s]
# Downloading data: 100%|██████████| 76.9M/76.9M [00:01<00:00, 39.1MB/s]
# Downloading data: 100%|██████████| 75.6M/75.6M [00:01<00:00, 51.8MB/s]
# Downloading data: 100%|██████████| 80.2M/80.2M [00:02<00:00, 36.8MB/s]
# Downloading data: 100%|██████████| 79.2M/79.2M [00:02<00:00, 34.3MB/s]
# Generating train split: 100%|██████████| 6282/6282 [00:02<00:00, 2144.27 examples/s]

# %%
Dataset.hug_to_pandas()
# Out:
#           cik   sic                     company       date  \
# 0     1043277  4731  C H ROBINSON WORLDWIDE INC 2010-03-01
# 1       11199  2670                BEMIS CO INC 2010-03-01
# 2      822416  1531         PULTE HOMES INC/MI/ 2010-02-19
# 3     1021860  3533  NATIONAL OILWELL VARCO INC 2010-02-26
# 4     1111711  4931             NISOURCE INC/DE 2010-02-26
# ...       ...   ...                         ...        ...
# 6277  1868275  4911   Constellation Energy Corp 2022-02-25
# 6278    78003  2834                  PFIZER INC 2022-02-24
# 6279    66740  3841                       3M CO 2022-02-09
# 6280  1524472  3561                  Xylem Inc. 2022-02-25
# 6281  1116132  3100              TAPESTRY, INC. 2022-08-18
#
#                                                  item_1  \
# 0     Item 1. BUSINESS\nOverview\nC.H. Robinson Worl...
# 1     ITEM 1 - BUSINESS\nBemis Company, Inc., a Miss...
# 2
# 3     ITEM 1. BUSINESS\nGeneral\nNational Oilwell Va...
# 4     ITEM 1.\nBUSINESS\nNiSource Inc.\nNiSource is ...
# ...                                                 ...
# 6277  ITEM 1.\nGeneral\nOn February 21, 2021, the bo...
# 6278  ITEM 1. BUSINESS\nABOUT PFIZER\nPfizer Inc. is...
# 6279  Item 1. Business.\n3M Company was incorporated...
# 6280  ITEM 1. BUSINESS\nBusiness Overview\nXylem is ...
# 6281  ITEM 1. BUSINESS\nFounded in 1941, Coach, Inc....
#
#                                                 item_1A  \
# 0     ITEM 1A. RISK FACTORS\nYou should consider car...
# 1     ITEM 1A - RISK FACTORS\nThe following factors,...
# 2     ITEM 1A. RISK FACTORS\nDiscussion of our busin...
# 3     ITEM 1A. RISK FACTORS\nYou should carefully co...
# 4     ITEM 1A.\nRISK FACTORS\nNiSource Inc.\nThere a...
# ...                                                 ...
# 6277  ITEM 1A. RISK FACTORS\nWe operate in a complex...
# 6278
# 6279  Item 1A. Risk Factors\nProvided below is a cau...
# 6280  ITEM 1A. RISK FACTORS\nIn evaluating our busin...
# 6281  ITEM 1A. RISK FACTORS\nYou should consider car...
#
#                                                 item_1B  \
# 0             ITEM 1B. UNRESOLVED STAFF COMMENTS\nNone.
# 1            ITEM 1B - UNRESOLVED STAFF COMMENTS\nNone.
# 2     ITEM 1B. UNRESOLVED STAFF COMMENTS\nThis Item ...
# 3             ITEM 1B. UNRESOLVED STAFF COMMENTS\nNone.
# 4             ITEM 1B. UNRESOLVED STAFF COMMENTS\nNone.
# ...                                                 ...
# 6277          ITEM 1B. UNRESOLVED STAFF COMMENTS\nNone.
# 6278
# 6279         Item 1B. Unresolved Staff Comments.\nNone.
# 6280         ITEM 1B. UNRESOLVED STAFF COMMENTS.\nNone.
# 6281          ITEM 1B. UNRESOLVED STAFF COMMENTS\nNone.
#
#                                                  item_2  \
# 0     ITEM 2. PROPERTIES\nOur corporate headquarters...
# 1     ITEM 2 - PROPERTIES\nProperties utilized by th...
# 2     ITEM 2. PROPERTIES\nOur homebuilding and corpo...
# 3     ITEM 2. PROPERTIES\nThe Company owned or lease...
# 4     ITEM 2.\nPROPERTIES\nNiSource Inc.\nDiscussed ...
# ...                                                 ...
# 6277  ITEM 2. PROPERTIES\nThe following table presen...
# 6278  ITEM 2. PROPERTIES\nWe own and lease space glo...
# 6279  Item 2. Properties.\nIn the U.S., 3M’s general...
# 6280  ITEM 2. PROPERTIES\nWe have approximately 345 ...
# 6281  ITEM 2. PROPERTIES\nThe following table sets f...
#
#                                                  item_3  \
# 0     ITEM 3. LEGAL PROCEEDINGS\nGender Discriminati...
# 1     ITEM 3 - LEGAL PROCEEDINGS\nThe Company is inv...
# 2     ITEM 3. LEGAL PROCEEDINGS\nWe are involved in ...
# 3     ITEM 3. LEGAL PROCEEDINGS\nWe have various cla...
# 4     ITEM 3.\nLEGAL PROCEEDINGS\nNiSource Inc.\n1. ...
# ...                                                 ...
# 6277  ITEM 3. LEGAL PROCEEDINGS\nWe are parties to v...
# 6278  ITEM 3. LEGAL PROCEEDINGS\nCertain legal proce...
# 6279  Item 3. Legal Proceedings.\nDiscussion of lega...
# 6280  ITEM 3. LEGAL PROCEEDINGS\nFrom time to time, ...
# 6281  ITEM 3. LEGAL PROCEEDINGS\nInformation regardi...
#
#                                                  item_4  ... 5_day_return  \
# 0                             ITEM 4. RESERVED\nPART II  ...     1.000262
# 1     ITEM 4 - [RESERVED]\nPART II - ITEMS 5, 6, 7, ...  ...     1.002702
# 2     ITEM 4. SUBMISSION OF MATTERS TO A VOTE OF SEC...  ...     0.947507
# 3     ITEM 4. SUBMISSION OF MATTERS TO A VOTE OF SEC...  ...     1.004371
# 4     ITEM 4.\nSUBMISSION OF MATTERS TO A VOTE OF SE...  ...     1.023968
# ...                                                 ...  ...          ...
# 6277  ITEM 4. MINE SAFETY DISCLOSURES\nNot Applicabl...  ...     1.161467
# 6278                                                     ...     1.040688
# 6279  Item 4. Mine Safety Disclosures.\nPursuant to ...  ...     0.951051
# 6280  ITEM 4. MINE SAFETY DISCLOSURES\nNot applicabl...  ...     0.937534
# 6281  ITEM 4. MINE SAFETY DISCLOSURES\nNot applicabl...  ...     0.978706
#
#      10_day_return 20_day_return 40_day_return 60_day_return 80_day_return  \
# 0         1.010768      1.052226      1.130642      1.076802      1.082564
# 1         1.002364      0.988180      1.034786      0.963769      0.976024
# 2         0.982502      0.979877      0.972003      1.019248      0.868766
# 3         1.013125      0.920435      1.070998      0.831666      0.829176
# 4         1.031292      1.050599      1.105193      0.995317      1.018275
# ...            ...           ...           ...           ...           ...
# 6277      1.123207      1.225233      1.418128      1.292399      1.351996
# 6278      1.070496      1.144256      1.047215      1.150707      1.055089
# 6279      0.886950      0.888369      0.925526      0.922934      0.911592
# 6280      0.919609      0.953371      0.924337      0.893434      0.833604
# 6281      0.929199      0.873899      0.812686      0.949610      1.010374
#
#      100_day_return 150_day_return 252_day_return __index_level_0__
# 0          1.119114       1.316981       1.373999                 2
# 1          1.009387       1.096707       1.144034                20
# 2          0.747157       0.715661       0.678915                38
# 3          0.846518       1.030842       1.853791                39
# 4          1.068919       1.191144       1.330613                42
# ...             ...            ...            ...               ...
# 6277       1.236685       1.902839       1.902839              6395
# 6278       1.114522       0.976100       0.976100              6401
# 6279       0.809528       0.733305       0.733305              6445
# 6280       0.915728       0.967472       0.967472              6456
# 6281       1.010374       1.010374       1.010374              6473
#
# [6282 rows x 38 columns]
